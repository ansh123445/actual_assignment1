# %% [raw]
# que1.explain the key feature of python that makes it a popular programming.
#
# solution:the features that makes it popular programming language are:
#
# 1.simple and easy to implement.
# 2.many libraries.
# 3.interpreted language
# 4.versatility.

# %% [raw]
# que2.Describe the role of predefined keywords in Python and provide examples of how they are used in a program.
#
# solution:Predefined keywords in Python are reserved words that have special meanings and cannot be used as identifiers .
# some of them are:
# 1.conditional statements:if,if else,if elif else,etc...
# eg:age=80
#    if age>=20:
#      print("young")
#    elif age>=45:
#      print("mid age")
#    else:
#     print("old person")
#
# 2.loop statements:for,while,etc....
# eg:
# l=[1,2,3,"pw"]
# for i in range(l):
#     print(i)

# %% [raw]
# que3.Compare and contrast mutable and immutable objects in Python with examples.
#
# solution:Mutable objects can have their state or contents changed after they are created.
#
# Examples: Lists, dictionaries, sets, bytearrays, etc.
#
# code:
# list_count=[1,2,"vikram","pw"]
# list_count[2]="skills"
#
# output:[1,2,"skills","pw"]
#
#
# Immutable objects cannot be changed after they are created.
#
# Examples: Strings, tuples, numbers (integers, floats), frozensets, bytes, etc.
#
# code:
# list_count="pwskills"
# list_count[0]="1"
# output:it will show error

# %% [raw]
# que4.Discuss the different types of operators in Python and provide examples of how they are used.
#
# solution:
# There are different type of operstors in python and some of them are:
#
# 1.Arithmetic operator:These operators are used to perform mathematical operations
# eg:
# 1.result = 4 + 2 # Output: 6
# 2.result = 9 - 4 # Output: 5
#
# 2.Comparison Operators:
# These operators compare two values and return a boolean result.
# eg:
# 1.result = (5 != 3)  # Output: True
# 2.result = (5 > 3)  # Output: True
#
#
# 3.Logical Operators
# These operators are used to combine conditional statements.
# eg:
# 1.result = (5 > 3 and 2 < 4)  # Output: True
# 2.result = (5 > 3 or 2 > 4)  # Output: True

# %% [raw]
# que5.explain the concept of type casting in Python with examples.
#
# solution:Type casting in Python refers to the conversion of one data type into another. This can be done using various functions provided by Python to ensure that operations and comparisons are performed correctly. There are two types of type casting: implicit and explicit.
#
# Implicit Type Casting
# Implicit type casting, or coercion, is automatically performed by Python when an operation involves different data types. Python converts the data type to avoid loss of data.
# eg:a=5
# type(a)
# output:int
#
# Explicit Type Casting
# Explicit type casting, or type conversion, is done manually by the programmer using built-in functions to convert data from one type to another.
# eg:a="2"
# print(type(int(a)))
# output:int

# %% [raw]
# que6. How do conditional statements work in Python? Illustrate with examples
#
# solution:Conditional statements in Python are used to execute a block of code only if a specified condition is true. They help in making decisions in the program flow based on certain conditions. The primary conditional statements in Python are if, elif, and else.
#
# if Statement
# The if statement evaluates a condition and executes the block of code inside it if the condition is true.
# eg:
# x = 10
# if x > 5:
#     print("x is greater than 5")
#
# if-else Statement
# The if-else statement adds an alternative block of code that will be executed if the condition in the if statement is false.
# eg:
# x = 3
#
# if x > 5:
#     print("x is greater than 5")
# else:
#     print("x is not greater than 5")
#
# if-elif-else Statement
# The if-elif-else statement is used when you have multiple conditions to check. The elif statement checks another condition if the previous conditions were false.
# eg:
#    age=80
#    if age>=20:
#      print("young")
#    elif age>=45:
#      print("mid age")
#    else:
#     print("old person")

# %% [raw]
# que7.Describe the different types of loops in Python and their use cases with examples.
#
# solution:
#
# In Python, loops are used to execute a block of code repeatedly until a certain condition is met. There are two main types of loops in Python: for loops and while loops. Each type of loop has its own specific use cases and syntax. Additionally, Python provides control flow statements like break, continue, and pass to alter the behavior of loops.
#
# 1. for Loop
# A for loop is used for iterating over a sequence (such as a list, tuple, dictionary, set, or string) or other iterable objects. It repeats a block of code for each item in the sequence.
#
# eg:
# l=[1,2,3,"pw"]
# for i in range(l):
#     print(i)
#
# 2. while Loop
# A while loop repeatedly executes a block of code as long as a specified condition is true. The condition is evaluated before the execution of the loop's code block.
#
# eg:
# count = 0
# while count < 5:
#     print(count)
#     count += 1
